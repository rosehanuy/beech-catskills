# %%
from pathlib import Path
import spectral as spy

root = Path.cwd()

# %% [markdown]
# spy.open_image doesn't work with neon h5 data
# - raises error 'File size not consistent with AVIRIS format' https://github.com/spectralpython/spectral/issues/55

# %%
img  = spy.open_image(root / 'aviris_data'/ 'f090705t01p00r09rdn_b'/'f090705t01p00r09rdn_b_ort_img.hdr')

# %%
# display random patch of image
view = spy.imshow(img[500:800,500:800,:], (29, 19, 9))
